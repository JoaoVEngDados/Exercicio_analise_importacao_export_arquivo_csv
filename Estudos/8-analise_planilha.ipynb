# %%
import pandas as pd

# %%
df = pd.read_excel("dados/campeonato.xlsx")
df
# Out:
#          Times  Partidas_Jogadas  Vitorias  Empates  Derrotas  Gols_Pro  \
# 0    Palmeiras                10         9        3         2        18
# 1     Flamengo                10         7        2         1        22
# 2  Corintinhas                10         6        3         3        14
# 3    São Paulo                10         4        1         3        16
# 4       Santos                10         3        2         5        10
#
#    Gols_Contra  Saldo_Gols  Pontos
# 0           12           6      30
# 1           10          12      23
# 2           16          -2      21
# 3           15           1      13
# 4           20         -10      11

# %%
df.dtypes
# Out:
# Times                 str
# Partidas_Jogadas    int64
# Vitorias            int64
# Empates             int64
# Derrotas            int64
# Gols_Pro            int64
# Gols_Contra         int64
# Saldo_Gols          int64
# Pontos              int64
# dtype: object

# %%
df.describe()
# Out:
#        Partidas_Jogadas  Vitorias  Empates  Derrotas   Gols_Pro  Gols_Contra  \
# count               5.0  5.000000  5.00000   5.00000   5.000000     5.000000
# mean               10.0  5.800000  2.20000   2.80000  16.000000    14.600000
# std                 0.0  2.387467  0.83666   1.48324   4.472136     3.847077
# min                10.0  3.000000  1.00000   1.00000  10.000000    10.000000
# 25%                10.0  4.000000  2.00000   2.00000  14.000000    12.000000
# 50%                10.0  6.000000  2.00000   3.00000  16.000000    15.000000
# 75%                10.0  7.000000  3.00000   3.00000  18.000000    16.000000
# max                10.0  9.000000  3.00000   5.00000  22.000000    20.000000
#
#        Saldo_Gols     Pontos
# count    5.000000   5.000000
# mean     1.400000  19.600000
# std      8.294577   7.733046
# min    -10.000000  11.000000
# 25%     -2.000000  13.000000
# 50%      1.000000  21.000000
# 75%      6.000000  23.000000
# max     12.000000  30.000000

# %%
df.head(4)
# Out:
#          Times  Partidas_Jogadas  Vitorias  Empates  Derrotas  Gols_Pro  \
# 0    Palmeiras                10         9        3         2        18
# 1     Flamengo                10         7        2         1        22
# 2  Corintinhas                10         6        3         3        14
# 3    São Paulo                10         4        1         3        16
#
#    Gols_Contra  Saldo_Gols  Pontos
# 0           12           6      30
# 1           10          12      23
# 2           16          -2      21
# 3           15           1      13

# %%
df.tail(4)
# Out:
#          Times  Partidas_Jogadas  Vitorias  Empates  Derrotas  Gols_Pro  \
# 1     Flamengo                10         7        2         1        22
# 2  Corintinhas                10         6        3         3        14
# 3    São Paulo                10         4        1         3        16
# 4       Santos                10         3        2         5        10
#
#    Gols_Contra  Saldo_Gols  Pontos
# 1           10          12      23
# 2           16          -2      21
# 3           15           1      13
# 4           20         -10      11

# %%
#1 - Analise de Desempenho por Time
desempenho_info = df[['Times','Pontos','Vitorias','Saldo_Gols']].set_index('Times')
desempenho_info
# Out:
#              Pontos  Vitorias  Saldo_Gols
# Times
# Palmeiras        30         9           6
# Flamengo         23         7          12
# Corintinhas      21         6          -2
# São Paulo        13         4           1
# Santos           11         3         -10

# %%
#2-Time com  menos vitorias
times_menos_vitorias = df[df['Vitorias'] == df['Vitorias'].min()]
times_menos_vitorias
# Out:
#     Times  Partidas_Jogadas  Vitorias  Empates  Derrotas  Gols_Pro  \
# 4  Santos                10         3        2         5        10
#
#    Gols_Contra  Saldo_Gols  Pontos
# 4           20         -10      11

# %%
#3-Distribuição de Gols Pró
df['Gols_Pro'].value_counts()
# Out:
# Gols_Pro
# 18    1
# 22    1
# 14    1
# 16    1
# 10    1
# Name: count, dtype: int64

# %%
#4-Relação entre gols pró e contras
correlacao = df['Gols_Pro'].corr(df['Pontos'])
print(correlacao)
# Out:
# 0.6506042984620202

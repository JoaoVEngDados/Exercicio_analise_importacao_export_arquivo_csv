# %%
import json

# %%
dados_receitas = {
    "receitas" : [
        {
        "titulo": "Bolo de Chocolate",
        "tempo_preparo": "45 minutos",
        "porcoes": 8,
        "ingredientes": [
            {"ingrediente":"Farinha de trigo","quantidade": "2 xicaras"},
            {"ingrediente": "Açúcar","quantidade": "1 xicara"},
            {"ingrediente": "Ovos","quantidade":"3 xicaras"},
            {"ingrediente":"leite","quantidade":"1 xicara"},
            {"ingrediente": "Manteiga","quantidade":"1/2 xicara"}
        
        ]
        
        },
        {
            "titulo": "Salada Caesar",
            "tempo_preparo": "20 minutos",
            "porcoes": 4,
            "ingredientes": [
                {"ingredientes": "Alface romana","quantidade": "1 cabeça"},
                {"ingrediente": "Croutons","quantidade":"1 xicara"},
                {"ingrediente":"Queijo parmesão","quantidade":"1/2 xicara"},
                {"ingrediente":"Molho caesar","quantidade":"1/4 xicara"}

            ]
        },
        {
            "titulo": "Pasta ao Pesto",
            "tempo_preparo": "30 minutos",
            "porcoes":2,
            "ingredientes ":[
                {"ingrediente":"Massa","quantidade": "200g"},
                {"ingrediente":"Manjericão fresco","quantidade":"1/2 xicara"},
                {"ingrediente":"Azeite de oliva","quantidade":"1/3 xicara"},
                {"ingrediente": "Nozes","quantidade":"1/4 xicara"},
                {"ingrediente":"Queijo parmesão","quantidade":"1/4 xicara"}
            ]
        }
    ]
}

# %%
with open(r"C:\Users\joaoe.DESKTOP-53TM428\OneDrive\Documents\Pandas\Estudos\receitas.json","w",encoding="utf-8") as arquivo_json:
    json.dump(dados_receitas, arquivo_json ,ensure_ascii=False,indent=4)

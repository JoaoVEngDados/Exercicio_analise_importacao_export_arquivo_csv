# %%
import pandas as pd

# %%
dados_vendas = {
    'Produtos' : ['Camisa','Calça','Saia','Camisa','Calça','Saia','Camiseta','Calça','Saia'],
    'Preço' : [50,100,80,55,110,85,45,95,90],
    'Quantidade' : [10,15,20,5,10,15,30,20,10],
    'Mês' :['Jan','Jan','Jan','Fev','Fev','Fev','Mar','Mar','Mar']
}

# %%
df_vendas = pd.DataFrame(dados_vendas)
df_vendas
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 df_vendas = pd.DataFrame(dados_vendas)
#       2 df_vendas
#
# NameError: name 'dados_vendas' is not defined

# %%
# Calculando a Receita Total
df_vendas['Receita'] = df_vendas['Preço'] * df_vendas['Quantidade']
df_vendas
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 2
#       1 # Calculando a Receita Total
# ----> 2 df_vendas['Receita'] = df_vendas['Preço'] * df_vendas['Quantidade']
#       3 df_vendas
#
# NameError: name 'df_vendas' is not defined

# %%
# Sumarizando a receita total por produto
resumo_vendas = df_vendas.groupby('Produtos')['Receita'].sum().reset_index()
resumo_vendas
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[14], line 2
#       1 # Sumarizando a receita total por produto
# ----> 2 resumo_vendas = df_vendas.groupby('Produtos')['Receita'].sum().reset_index()
#       3 resumo_vendas
#
# NameError: name 'df_vendas' is not defined

# %%
# Filtrar produtos com receitas acima de $ 1000
produtos_altas_vendas = resumo_vendas[resumo_vendas['Receita']> 1000]
produtos_altas_vendas
# Out:
#    Produtos  Receita
# 0     Calça     4500
# 2  Camiseta     1350
# 3      Saia     3775

# %%
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(8,5))
plt.bar(resumo_vendas['Produtos'],resumo_vendas['Receita'], color='skyblue')
plt.title('Receita Total por Produto')
plt.xlabel('Produto')
plt.ylabel('Receita R$')
plt.xticks(rotation=45)
# Out:
# ([0, 1, 2, 3],
#  [Text(0, 0, 'Calça'),
#   Text(1, 0, 'Camisa'),
#   Text(2, 0, 'Camiseta'),
#   Text(3, 0, 'Saia')])
